# %% [markdown]
# <a href="https://colab.research.google.com/github/Qossai/Stock-Data/blob/main/Stock_data_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# In this project, I will create a Python script to fetch and
# maybe analyze stock market data for a given stock symbol.
import requests

apikey = '2R22LRD72YFK1TJG'

# Function to fetch stock data by symbol
def fetch_stock_data (symbol):
    base_url = 'https://www.alphavantage.co/query' #source is https://www.alphavantage.co/documentation/
    function = 'TIME_SERIES_DAILY' # source is https://www.alphavantage.co/documentation/
    params = {
        'function' : function,
        'symbol'   : symbol,
        'apikey'   : apikey,
    }

    response = requests.get(base_url, params) #send the GET request to the URL and store te response into the 'response' variable
    data = response.json() #parses the JSON data from the response body and converts it into a Python data structure and store it in the data variable
    return data

# Function to display stock data
def display_stock_data (data):
    if 'Time Series (Daily)' not in data: #based on the typical structure of the Alpha Vantage API response. https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo
        print ("The symbol is invalid, please try again later.")
        return

    print (f"stock symbol: {symbol}")
    print ("   date    |    open   |    high   |    low   |    close  | volume")
    print ('-' * 70)

    daily_price = data['Time Series (Daily)']
    for date, values in daily_price.items():
        open_price = values['1. open']
        high_price = values['2. high']
        low_price = values['3. low']
        close_price = values['4. close']
        volume = values['5. volume']

        print (f"{date} | {open_price} | {high_price} | {low_price} | {close_price} | {volume} ")

symbol = input("Enter the stock TIKR: ").upper()

data = fetch_stock_data (symbol)
display_stock_data(data)
# Out:
# Enter the stock TIKR: msft
# stock symbol: MSFT
#    date    |    open   |    high   |    low   |    close  | volume
# ----------------------------------------------------------------------
# 2023-11-24 | 377.3300 | 377.9700 | 375.1350 | 377.4300 | 10176649
# 2023-11-22 | 378.0000 | 379.7899 | 374.9650 | 377.8500 | 23361184
# 2023-11-21 | 375.6700 | 376.2215 | 371.1200 | 373.0700 | 28423145
# 2023-11-20 | 371.2200 | 378.8700 | 371.0000 | 377.4400 | 52528964
# 2023-11-17 | 373.6100 | 374.3700 | 367.0000 | 369.8500 | 40325371
# 2023-11-16 | 370.9600 | 376.3500 | 370.1800 | 376.1700 | 27182315
# 2023-11-15 | 371.2800 | 373.1300 | 367.1100 | 369.6700 | 26860095
# 2023-11-14 | 371.0100 | 371.9500 | 367.3454 | 370.2700 | 27683862
# 2023-11-13 | 368.2200 | 368.4700 | 365.9000 | 366.6800 | 19986506
# 2023-11-10 | 361.4900 | 370.1000 | 361.0700 | 369.6700 | 28065164
# 2023-11-09 | 362.3000 | 364.7900 | 360.3620 | 360.6900 | 24847331
# 2023-11-08 | 361.6800 | 363.8700 | 360.5500 | 363.2000 | 26767828
# 2023-11-07 | 359.4000 | 362.4600 | 357.6300 | 360.5300 | 25833931
# 2023-11-06 | 353.4500 | 357.5400 | 353.3500 | 356.5300 | 23828301
# 2023-11-03 | 349.6300 | 354.3900 | 347.3300 | 352.8000 | 23637673
# 2023-11-02 | 347.2400 | 348.8300 | 344.7700 | 348.3200 | 24348072
# 2023-11-01 | 339.7900 | 347.4200 | 339.6500 | 346.0700 | 28158819
# 2023-10-31 | 338.8500 | 339.0000 | 334.6900 | 338.1100 | 20265282
# 2023-10-30 | 333.4100 | 339.4500 | 331.8300 | 337.3100 | 22828082
# 2023-10-27 | 330.4250 | 336.7200 | 328.4007 | 329.8100 | 29856522
# 2023-10-26 | 340.5400 | 341.6300 | 326.9400 | 327.8900 | 37828543
# 2023-10-25 | 345.0200 | 346.2000 | 337.6200 | 340.6700 | 55053828
